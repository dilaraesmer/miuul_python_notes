# %% [markdown]
# <a href="https://colab.research.google.com/github/dilaraesmer/miuul_python_notes/blob/main/miuul_python_notes_7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
pd.set_option('display.max_columns', None)
pd.set_option('display.width', 500)

# %%
df = sns.load_dataset("titanic")

# %%
def check_df(dataframe, head=5):
  print("xxxxxx Shape xxxxxx")
  print(dataframe.shape)
  print("xxxxxx Types xxxxxx")
  print(dataframe.dtypes)
  print("xxxxxx Head xxxxxx")
  print(dataframe.head(head))
  print("xxxxxx Tail xxxxxx")
  print(dataframe.tail(head))
  print("xxxxxx NA xxxxxx")
  print(dataframe.isnull().sum())
  print("xxxxxx Quantiles xxxxxx")
  print(dataframe.describe([0, 0.05, 0.5, 0.95, 0.99, 1]).T)

# %%
check_df(df)
# Out:
# xxxxxx Shape xxxxxx
# (891, 15)
# xxxxxx Types xxxxxx
# survived          int64
# pclass            int64
# sex              object
# age             float64
# sibsp             int64
# parch             int64
# fare            float64
# embarked         object
# class          category
# who              object
# adult_male         bool
# deck           category
# embark_town      object
# alive            object
# alone              bool
# dtype: object
# xxxxxx Head xxxxxx
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class    who  adult_male deck  embark_town alive  alone
# 0         0       3    male  22.0      1      0   7.2500        S  Third    man        True  NaN  Southampton    no  False
# 1         1       1  female  38.0      1      0  71.2833        C  First  woman       False    C    Cherbourg   yes  False
# 2         1       3  female  26.0      0      0   7.9250        S  Third  woman       False  NaN  Southampton   yes   True
# ...

# %%
df_1 = sns.load_dataset("tips")

# %%
check_df(df_1)
# Out:
# xxxxxx Shape xxxxxx
# (244, 7)
# xxxxxx Types xxxxxx
# total_bill     float64
# tip            float64
# sex           category
# smoker        category
# day           category
# time          category
# size             int64
# dtype: object
# xxxxxx Head xxxxxx
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4
# xxxxxx Tail xxxxxx
#      total_bill   tip     sex smoker   day    time  size
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
# xxxxxx NA xxxxxx
# ...

# %%
df_2 = sns.load_dataset("flights")

# %%
check_df(df_2)
# Out:
# xxxxxx Shape xxxxxx
# (144, 3)
# xxxxxx Types xxxxxx
# year             int64
# month         category
# passengers       int64
# dtype: object
# xxxxxx Head xxxxxx
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121
# xxxxxx Tail xxxxxx
#      year month  passengers
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
# xxxxxx NA xxxxxx
# year          0
# month         0
# passengers    0
# dtype: int64
# xxxxxx Quantiles xxxxxx
#             count         mean         std     min      0%      5%     50%      95%      99%    100%     max
# year        144.0  1954.500000    3.464102  1949.0  1949.0  1949.0  1954.5  1960.00  1960.00  1960.0  1960.0
# passengers  144.0   280.298611  119.966317   104.0   104.0   121.6   265.5   488.15   585.79   622.0   622.0

# %%
df = sns.load_dataset("titanic")

# %%
df["class"].unique()
# Out:
# ['Third', 'First', 'Second']
# Categories (3, object): ['First', 'Second', 'Third']

# %%
df["class"].nunique()
# Out:
# 3

# %%
df.dtypes
# Out:
# survived          int64
# pclass            int64
# sex              object
# age             float64
# sibsp             int64
# parch             int64
# fare            float64
# embarked         object
# class          category
# who              object
# adult_male         bool
# deck           category
# embark_town      object
# alive            object
# alone              bool
# dtype: object

# %%
cat_cols = [col for col in df.columns if str(df[col].dtypes) in ["category", "object", "bool"]]

# %%
cat_cols
# Out:
# ['sex',
#  'embarked',
#  'class',
#  'who',
#  'adult_male',
#  'deck',
#  'embark_town',
#  'alive',
#  'alone']

# %%
df["sex"].dtypes
# Out:
# dtype('O')

# %%
str(df["sex"].dtypes)
# Out:
# 'object'

# %%
str(df["sex"].dtypes) in ["object"]
# Out:
# True

# %%
str(df["alone"].dtypes) in ["bool"]
# Out:
# True

# %%
num_but_cat = [col for col in df.columns if df[col].nunique() < 10 and df[col].dtypes in ["int", "float"] ]

# %%
num_but_cat
# Out:
# ['survived', 'pclass', 'sibsp', 'parch']

# %%
cat_but_car = [col for col in df.columns if df[col].nunique() > 20 and str(df[col].dtypes) in ["category", "object"]]

# %%
cat_but_car
# Out:
# []

# %%
cat_cols = [col for col in cat_cols if col not in cat_but_car]

# %%
df[cat_cols]
# Out:
#         sex embarked   class    who  adult_male deck  embark_town alive  alone
# 0      male        S   Third    man        True  NaN  Southampton    no  False
# 1    female        C   First  woman       False    C    Cherbourg   yes  False
# 2    female        S   Third  woman       False  NaN  Southampton   yes   True
# 3    female        S   First  woman       False    C  Southampton   yes  False
# 4      male        S   Third    man        True  NaN  Southampton    no   True
# ..      ...      ...     ...    ...         ...  ...          ...   ...    ...
# 886    male        S  Second    man        True  NaN  Southampton    no   True
# 887  female        S   First  woman       False    B  Southampton   yes   True
# 888  female        S   Third  woman       False  NaN  Southampton    no  False
# 889    male        C   First    man        True    C    Cherbourg   yes   True
# 890    male        Q   Third    man        True  NaN   Queenstown    no   True
#
# [891 rows x 9 columns]

# %%
df[cat_cols].nunique()
# Out:
# sex            2
# embarked       3
# class          3
# who            3
# adult_male     2
# deck           7
# embark_town    3
# alive          2
# alone          2
# dtype: int64

# %%
[col for col in df.columns if col not in cat_cols]
# Out:
# ['survived', 'pclass', 'age', 'sibsp', 'parch', 'fare']

# %%
df["survived"].value_counts()
100 * df["survived"].value_counts() / len(df)
# Out:
# 0    61.616162
# 1    38.383838
# Name: survived, dtype: float64

# %%
def cat_summary(dataframe, col_name):
  print(pd.DataFrame({col_name: dataframe[col_name].value_counts(),
                      "Ratio": 100 * dataframe[col_name].value_counts() / len(dataframe)}))

# %%
cat_summary(df, "sex")
# Out:
#         sex      Ratio
# male    577  64.758698
# female  314  35.241302

# %%
for col in cat_cols:
  cat_summary(df, col)
# Out:
#         sex      Ratio
# male    577  64.758698
# female  314  35.241302
#    embarked      Ratio
# S       644  72.278339
# C       168  18.855219
# Q        77   8.641975
#         class      Ratio
# Third     491  55.106622
# First     216  24.242424
# Second    184  20.650954
#        who      Ratio
# man    537  60.269360
# woman  271  30.415264
# child   83   9.315376
#        adult_male     Ratio
# True          537  60.26936
# False         354  39.73064
#    deck     Ratio
# C    59  6.621773
# B    47  5.274972
# D    33  3.703704
# E    32  3.591470
# A    15  1.683502
# F    13  1.459035
# G     4  0.448934
#              embark_town      Ratio
# Southampton          644  72.278339
# Cherbourg            168  18.855219
# Queenstown            77   8.641975
#      alive      Ratio
# no     549  61.616162
# yes    342  38.383838
#        alone     Ratio
# True     537  60.26936
# False    354  39.73064

# %%
def cat_summary(dataframe, col_name, plot = False):
  print(pd.DataFrame({col_name: dataframe[col_name].value_counts(),
                      "Ratio": 100 * dataframe[col_name].value_counts() / len(dataframe)}))
  print("xxxxxxxx")

  if plot:
    sns.countplot(x=dataframe[col_name], data=dataframe)
    plt.show(block=True)

# %%
cat_summary(df, "sex", plot = True)
# Out:
#         sex      Ratio
# male    577  64.758698
# female  314  35.241302
# xxxxxxxx

# %%
df["adult_male"].astype(int)
# Out:
# 0      1
# 1      0
# 2      0
# 3      0
# 4      1
#       ..
# 886    1
# 887    0
# 888    0
# 889    1
# 890    1
# Name: adult_male, Length: 891, dtype: int64

# %%
df[["age", "fare"]].describe().T
# Out:
#       count       mean        std   min      25%      50%   75%       max
# age   714.0  29.699118  14.526497  0.42  20.1250  28.0000  38.0   80.0000
# fare  891.0  32.204208  49.693429  0.00   7.9104  14.4542  31.0  512.3292

# %%
num_cols = [col for col in df.columns if df[col].dtypes in ["int", "float"]]

# %%
num_cols = [col for col in num_cols if col not in cat_cols]

# %%
def num_summary(dataframe, numerical_col, plot=False): 
  quantiles = [0.05, 0.10, 0.20, 0.30, 0.40, 0.50, 0.60, 0.70, 0.80]
  print(dataframe[numerical_col].describe(quantiles).T)
  if plot:
    dataframe[numerical_col].hist()
    plt.xlabel(numerical_col)
    plt.title(numerical_col)
    plt.show(block=True)

# %%
num_summary(df, "age", plot=True)
# Out:
# count    714.000000
# mean      29.699118
# std       14.526497
# min        0.420000
# 5%         4.000000
# 10%       14.000000
# 20%       19.000000
# 30%       22.000000
# 40%       25.000000
# 50%       28.000000
# 60%       31.800000
# 70%       36.000000
# 80%       41.000000
# max       80.000000
# Name: age, dtype: float64

# %%
for col in num_cols:
  num_summary(df, col, plot=True)
# Out:
# count    891.000000
# mean       0.383838
# std        0.486592
# min        0.000000
# 5%         0.000000
# 10%        0.000000
# 20%        0.000000
# 30%        0.000000
# 40%        0.000000
# 50%        0.000000
# 60%        0.000000
# 70%        1.000000
# 80%        1.000000
# max        1.000000
# Name: survived, dtype: float64
# count    891.000000
# mean       2.308642
# std        0.836071
# min        1.000000
# 5%         1.000000
# 10%        1.000000
# 20%        1.000000
# 30%        2.000000
# 40%        2.000000
# 50%        3.000000
# 60%        3.000000
# 70%        3.000000
# 80%        3.000000
# max        3.000000
# Name: pclass, dtype: float64
# count    714.000000
# mean      29.699118
# std       14.526497
# min        0.420000
# 5%         4.000000
# 10%       14.000000
# 20%       19.000000
# 30%       22.000000
# 40%       25.000000
# 50%       28.000000
# 60%       31.800000
# 70%       36.000000
# 80%       41.000000
# max       80.000000
# ...

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class    who  adult_male deck  embark_town alive  alone
# 0         0       3    male  22.0      1      0   7.2500        S  Third    man        True  NaN  Southampton    no  False
# 1         1       1  female  38.0      1      0  71.2833        C  First  woman       False    C    Cherbourg   yes  False
# 2         1       3  female  26.0      0      0   7.9250        S  Third  woman       False  NaN  Southampton   yes   True
# 3         1       1  female  35.0      1      0  53.1000        S  First  woman       False    C  Southampton   yes  False
# 4         0       3    male  35.0      0      0   8.0500        S  Third    man        True  NaN  Southampton    no   True

# %%
df["survived"].value_counts()
# Out:
# 0    549
# 1    342
# Name: survived, dtype: int64

# %%
df.groupby("sex")["survived"].mean()
# Out:
# sex
# female    0.742038
# male      0.188908
# Name: survived, dtype: float64

# %%
def target_summary_with_cat(dataframe, target, categorical_col):
 print(pd.DataFrame({"TARGET_MEAN": dataframe.groupby(categorical_col)[target].mean()}))

# %%
target_summary_with_cat(df, "survived", "pclass")
# Out:
#         TARGET_MEAN
# pclass
# 1          0.629630
# 2          0.472826
# 3          0.242363

# %%
target_summary_with_cat(df, "survived", "sex")
# Out:
#         TARGET_MEAN
# sex
# female     0.742038
# male       0.188908

# %%
for col in cat_cols:
  target_summary_with_cat(df, "survived", col)
# Out:
#         TARGET_MEAN
# sex
# female     0.742038
# male       0.188908
#           TARGET_MEAN
# embarked
# C            0.553571
# Q            0.389610
# S            0.336957
#         TARGET_MEAN
# class
# First      0.629630
# Second     0.472826
# Third      0.242363
#        TARGET_MEAN
# who
# child     0.590361
# man       0.163873
# woman     0.756458
#             TARGET_MEAN
# adult_male
# False          0.717514
# True           0.163873
#       TARGET_MEAN
# deck
# A        0.466667
# B        0.744681
# C        0.593220
# D        0.757576
# E        0.750000
# F        0.615385
# G        0.500000
#              TARGET_MEAN
# embark_town
# Cherbourg       0.553571
# Queenstown      0.389610
# Southampton     0.336957
#        TARGET_MEAN
# alive
# no             0.0
# yes            1.0
#        TARGET_MEAN
# alone
# False     0.505650
# True      0.303538

# %%
df.groupby("survived")["age"].mean()
# Out:
# survived
# 0    30.626179
# 1    28.343690
# Name: age, dtype: float64

# %%
df.groupby("survived").agg({"age": "mean"})
# Out:
#                 age
# survived
# 0         30.626179
# 1         28.343690

# %%
def target_summary_with_num(dataframe, target, numerical_col):
 print(dataframe.groupby(target).agg({numerical_col: "mean"}))

# %%
target_summary_with_num(df, "survived", "age")
# Out:
#                 age
# survived
# 0         30.626179
# 1         28.343690

# %%
df = pd.read_csv("breast-cancer.csv")

# %%
df = df.iloc[:, 1:-1]

# %%
df.head()
# Out:
#   diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  compactness_mean  concavity_mean  concave points_mean  symmetry_mean  fractal_dimension_mean  radius_se  texture_se  perimeter_se  area_se  smoothness_se  compactness_se  concavity_se  concave points_se  symmetry_se  fractal_dimension_se  radius_worst  texture_worst  perimeter_worst  area_worst  smoothness_worst  compactness_worst  concavity_worst  concave points_worst  symmetry_worst
# 0         M        17.99         10.38          122.80     1001.0          0.11840           0.27760          0.3001              0.14710         0.2419                 0.07871     1.0950      0.9053         8.589   153.40       0.006399         0.04904       0.05373            0.01587      0.03003              0.006193         25.38          17.33           184.60      2019.0            0.1622             0.6656           0.7119                0.2654          0.4601
# ...

# %%
num_cols = [col for col in df.columns if df[col].dtype in [int, float]]

# %%
corr = df[num_cols].corr()

# %%
corr
# Out:
#                         radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  compactness_mean  concavity_mean  concave points_mean  symmetry_mean  fractal_dimension_mean  radius_se  texture_se  perimeter_se   area_se  smoothness_se  compactness_se  concavity_se  concave points_se  symmetry_se  fractal_dimension_se  radius_worst  texture_worst  perimeter_worst  area_worst  smoothness_worst  compactness_worst  concavity_worst  concave points_worst  symmetry_worst
# radius_mean                1.000000      0.323782        0.997855   0.987357         0.170581          0.506124        0.676764             0.822529       0.147741               -0.311631   0.679090   -0.097317      0.674172  0.735864      -0.222600        0.206000      0.194204           0.376169    -0.104321             -0.042641      0.969539       0.297008         0.965137    0.941082          0.119616           0.413463         0.526911              0.744214        0.163953
# ...

# %%
sns.set(rc={'figure.figsize': (12, 12)})
sns.heatmap(corr, cmap="RdBu")
plt.show()

# %%
cor_matrix= df.corr().abs()

# %%
cor_matrix
# Out:
#                         radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  compactness_mean  concavity_mean  concave points_mean  symmetry_mean  fractal_dimension_mean  radius_se  texture_se  perimeter_se   area_se  smoothness_se  compactness_se  concavity_se  concave points_se  symmetry_se  fractal_dimension_se  radius_worst  texture_worst  perimeter_worst  area_worst  smoothness_worst  compactness_worst  concavity_worst  concave points_worst  symmetry_worst
# radius_mean                1.000000      0.323782        0.997855   0.987357         0.170581          0.506124        0.676764             0.822529       0.147741                0.311631   0.679090    0.097317      0.674172  0.735864       0.222600        0.206000      0.194204           0.376169     0.104321              0.042641      0.969539       0.297008         0.965137    0.941082          0.119616           0.413463         0.526911              0.744214        0.163953
# ...

# %%
upper_triangel_matrix = cor_matrix.where(np.triu(np.ones(cor_matrix.shape), k=1).astype(np.bool))
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   """Entry point for launching an IPython kernel.

# %%
upper_triangel_matrix
# Out:
#                         radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  compactness_mean  concavity_mean  concave points_mean  symmetry_mean  fractal_dimension_mean  radius_se  texture_se  perimeter_se   area_se  smoothness_se  compactness_se  concavity_se  concave points_se  symmetry_se  fractal_dimension_se  radius_worst  texture_worst  perimeter_worst  area_worst  smoothness_worst  compactness_worst  concavity_worst  concave points_worst  symmetry_worst
# radius_mean                     NaN      0.323782        0.997855   0.987357         0.170581          0.506124        0.676764             0.822529       0.147741                0.311631   0.679090    0.097317      0.674172  0.735864       0.222600        0.206000      0.194204           0.376169     0.104321              0.042641      0.969539       0.297008         0.965137    0.941082          0.119616           0.413463         0.526911              0.744214        0.163953
# ...

# %%
drop_list = [col for col in upper_triangel_matrix.columns if any(upper_triangel_matrix[col] > 0.90)]

# %%
drop_list
# Out:
# ['perimeter_mean',
#  'area_mean',
#  'concave points_mean',
#  'perimeter_se',
#  'area_se',
#  'radius_worst',
#  'texture_worst',
#  'perimeter_worst',
#  'area_worst',
#  'concave points_worst']

# %%
cor_matrix[drop_list]
# Out:
#                         perimeter_mean  area_mean  concave points_mean  perimeter_se   area_se  radius_worst  texture_worst  perimeter_worst  area_worst  concave points_worst
# radius_mean                   0.997855   0.987357             0.822529      0.674172  0.735864      0.969539       0.297008         0.965137    0.941082              0.744214
# texture_mean                  0.329533   0.321086             0.293464      0.281673  0.259845      0.352573       0.912045         0.358040    0.343546              0.295316
# perimeter_mean                1.000000   0.986507             0.850977      0.693135  0.744983      0.969476       0.303038         0.970387    0.941550              0.771241
# area_mean                     0.986507   1.000000             0.823269      0.726628  0.800086      0.962746       0.287489         0.959120    0.959213              0.722017
# ...

# %%
df.drop(drop_list, axis=1)
# Out:
#     diagnosis  radius_mean  texture_mean  smoothness_mean  compactness_mean  concavity_mean  symmetry_mean  fractal_dimension_mean  radius_se  texture_se  smoothness_se  compactness_se  concavity_se  concave points_se  symmetry_se  fractal_dimension_se  smoothness_worst  compactness_worst  concavity_worst  symmetry_worst
# 0           M        17.99         10.38          0.11840           0.27760         0.30010         0.2419                 0.07871     1.0950      0.9053       0.006399         0.04904       0.05373            0.01587      0.03003              0.006193           0.16220            0.66560           0.7119          0.4601
# 1           M        20.57         17.77          0.08474           0.07864         0.08690         0.1812                 0.05667     0.5435      0.7339       0.005225         0.01308       0.01860            0.01340      0.01389              0.003532           0.12380            0.18660           0.2416          0.2750
# ...

# %%
df.shape
# Out:
# (569, 30)
