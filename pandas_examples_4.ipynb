# %% [markdown]
# <a href="https://colab.research.google.com/github/dilaraesmer/miuul_python_notes/blob/main/pandas_examples_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv('survey_results_public.csv', index_col = 'Respondent')
schema_df = pd.read_csv('survey_results_schema.csv', index_col = 'Column')

# %%
pd.set_option('display.max_columns', 153)
pd.set_option('display.max_rows', 153)

# %%
df.head()
# Out:
#                                                  Professional  \
# Respondent
# 1                                                     Student
# 2                                                     Student
# 3                                      Professional developer
# 4           Professional non-developer who sometimes write...
# 5                                      Professional developer
#
#                          ProgramHobby         Country      University  \
# Respondent
# 1                           Yes, both   United States              No
# 2                           Yes, both  United Kingdom  Yes, full-time
# 3                           Yes, both  United Kingdom              No
# 4                           Yes, both   United States              No
# 5           Yes, I program as a hobby     Switzerland              No
#
#                                   EmploymentStatus  \
# Respondent
# 1           Not employed, and not looking for work
# ...

# %%
df['Salary'].head(15)
# Out:
# Respondent
# 1          NaN
# 2          NaN
# 3     113750.0
# 4          NaN
# 5          NaN
# 6          NaN
# 7          NaN
# 8          NaN
# 9          NaN
# 10         NaN
# 11         NaN
# 12         NaN
# 13         NaN
# 14         NaN
# 15    100000.0
# Name: Salary, dtype: float64

# %%
df['Salary'].head(15).median()
# Out:
# 106875.0

# %%
df.median()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   """Entry point for launching an IPython kernel.
# CareerSatisfaction               8.000000
# JobSatisfaction                  7.000000
# HoursPerWeek                     1.000000
# StackOverflowSatisfaction        8.000000
# Salary                       51612.903226
# ExpectedSalary               29784.946237
# dtype: float64

# %%
df.describe()
# Out:
#        CareerSatisfaction  JobSatisfaction  HoursPerWeek  \
# count        16102.000000     15253.000000   7721.000000
# mean             7.343932         7.000721      3.685922
# std              1.919330         2.128648      7.330691
# min              0.000000         0.000000      0.000000
# 25%              6.000000         6.000000      0.000000
# 50%              8.000000         7.000000      1.000000
# 75%              9.000000         8.000000      3.000000
# max             10.000000        10.000000     40.000000
#
#        StackOverflowSatisfaction         Salary  ExpectedSalary
# count               13452.000000    5009.000000      818.000000
# mean                    8.357865   58341.398571    32231.521687
# std                     1.405546   40753.384986    28543.877274
# min                     0.000000       0.000000        0.000000
# 25%                     8.000000   27956.989247     4716.459735
# 50%                     8.000000   51612.903226    29784.946237
# ...

# %%
df['Salary'].count()
# Out:
# 5009

# %%
df['ProgramHobby']
# Out:
# Respondent
# 1                        Yes, both
# 2                        Yes, both
# 3                        Yes, both
# 4                        Yes, both
# 5        Yes, I program as a hobby
#                    ...
# 19098    Yes, I program as a hobby
# 19099    Yes, I program as a hobby
# 19100    Yes, I program as a hobby
# 19101    Yes, I program as a hobby
# 19102    Yes, I program as a hobby
# Name: ProgramHobby, Length: 19102, dtype: object

# %%
df['ProgramHobby'].value_counts()
# Out:
# Yes, I program as a hobby                    9260
# Yes, both                                    5033
# No                                           3661
# Yes, I contribute to open source projects    1148
# Name: ProgramHobby, dtype: int64

# %%
df['SelfTaughtTypes']
# Out:
# Respondent
# 1                                                      NaN
# 2        Official documentation; Stack Overflow Q&A; Other
# 3        Official documentation; Trade book; Textbook; ...
# 4                                                      NaN
# 5                                                      NaN
#                                ...
# 19098    Official documentation; Stack Overflow Q&A; Fr...
# 19099                                                  NaN
# 19100                                                  NaN
# 19101                                           Trade book
# 19102                                                  NaN
# Name: SelfTaughtTypes, Length: 19102, dtype: object

# %%
schema_df.loc['SelfTaughtTypes', 'Question']
# Out:
# "You indicated that you had taught yourself a programming technology without taking a course. What resources did you use to do that? If you've done it more than once, please think about the most recent time you've done so."

# %%
df['SelfTaughtTypes'].value_counts()
# Out:
# Official documentation; Trade book; Stack Overflow Q&A                                                                                     437
# Official documentation; Stack Overflow Q&A                                                                                                 391
# Official documentation; Stack Overflow Q&A; Non-Stack online communities; Built-in help                                                    378
# Official documentation; Stack Overflow Q&A; Built-in help                                                                                  373
# Official documentation; Trade book; Stack Overflow Q&A; Built-in help                                                                      321
#                                                                                                                                           ...
# ...

# %%
df['SelfTaughtTypes'].value_counts(normalize = True)
# Out:
# Official documentation; Trade book; Stack Overflow Q&A                                                                                     0.042957
# Official documentation; Stack Overflow Q&A                                                                                                 0.038435
# Official documentation; Stack Overflow Q&A; Non-Stack online communities; Built-in help                                                    0.037157
# Official documentation; Stack Overflow Q&A; Built-in help                                                                                  0.036666
# Official documentation; Trade book; Stack Overflow Q&A; Built-in help                                                                      0.031554
#                                                                                                                                              ...
# ...

# %%
df['Country']
# Out:
# Respondent
# 1         United States
# 2        United Kingdom
# 3        United Kingdom
# 4         United States
# 5           Switzerland
#               ...
# 19098            Canada
# 19099             India
# 19100    United Kingdom
# 19101     United States
# 19102            France
# Name: Country, Length: 19102, dtype: object

# %%
df['Country'].value_counts()
# Out:
# United States                     4364
# India                             1557
# United Kingdom                    1424
# Germany                           1337
# Canada                             874
#                                   ...
# Cayman Islands                       1
# S. Georgia & S. Sandwich Isls.       1
# Cape Verde                           1
# Virgin Islands (USA)                 1
# Ivory Coast (Cote D'Ivoire)          1
# Name: Country, Length: 165, dtype: int64

# %%
df['Country'].value_counts()
# Out:
# United States                     4364
# India                             1557
# United Kingdom                    1424
# Germany                           1337
# Canada                             874
#                                   ...
# Cayman Islands                       1
# S. Georgia & S. Sandwich Isls.       1
# Cape Verde                           1
# Virgin Islands (USA)                 1
# Ivory Coast (Cote D'Ivoire)          1
# Name: Country, Length: 165, dtype: int64

# %%
country_grp = df.groupby(['Country'])

# %%
country_grp.get_group('Turkey')
# Out:
#                                                  Professional  \
# Respondent
# 59                                     Professional developer
# 98                                     Professional developer
# 102                                             None of these
# 130                                    Professional developer
# 720                                    Professional developer
# 733                                    Professional developer
# 764                                    Professional developer
# 879                                             None of these
# 1076                                   Professional developer
# 1109        Professional non-developer who sometimes write...
# 1310                                   Professional developer
# 1406                                   Professional developer
# 1407        Professional non-developer who sometimes write...
# 1408        Professional non-developer who sometimes write...
# ...

# %%
filt = df['Country'] == 'Turkey'
df.loc[filt].head()
# Out:
#                       Professional               ProgramHobby Country  \
# Respondent
# 59          Professional developer                         No  Turkey
# 98          Professional developer                         No  Turkey
# 102                  None of these  Yes, I program as a hobby  Turkey
# 130         Professional developer  Yes, I program as a hobby  Turkey
# 720         Professional developer                         No  Turkey
#
#                 University    EmploymentStatus         FormalEducation  \
# Respondent
# 59          Yes, part-time  Employed full-time       Bachelor's degree
# 98                      No  Employed full-time       Bachelor's degree
# 102         Yes, part-time  Employed full-time       Bachelor's degree
# 130                     No  Employed full-time  I prefer not to answer
# 720                     No  Employed full-time       Bachelor's degree
#
#                                                MajorUndergrad  \
# Respondent
# ...

# %%
df.loc[filt]['SelfTaughtTypes'].value_counts()
# Out:
# Official documentation; Stack Overflow Q&A; Stack Overflow Docs; Non-Stack online communities; Built-in help                                                             3
# Official documentation; Trade book; Stack Overflow Q&A; Non-Stack online communities; Built-in help                                                                      3
# Official documentation; Stack Overflow Q&A; Built-in help                                                                                                                2
# Official documentation; Stack Overflow Q&A; Stack Overflow Docs; Non-Stack online communities                                                                            2
# Official documentation; Stack Overflow Q&A; Non-Stack online communities                                                                                                 2
# ...

# %%
filt_1 = df['ChallengeMyself'] == 'Strongly agree'
df.loc[filt_1]
# Out:
#                                                  Professional  \
# Respondent
# 4           Professional non-developer who sometimes write...
# 9                                      Professional developer
# 19                                     Professional developer
# 29          Professional non-developer who sometimes write...
# 33                                              None of these
# ...                                                       ...
# 19062                                  Professional developer
# 19075                                                 Student
# 19076                                  Professional developer
# 19080                                  Professional developer
# 19082                                  Professional developer
#
#                                          ProgramHobby        Country  \
# Respondent
# 4                                           Yes, both  United States
# ...

# %%
df.loc[filt_1]['ChallengeMyself'].value_counts()
# Out:
# Strongly agree    4419
# Name: ChallengeMyself, dtype: int64

# %%
country_grp['SelfTaughtTypes'].value_counts()
# Out:
# Country                   SelfTaughtTypes
# Afghanistan               Official documentation; Stack Overflow Q&A; Non-Stack online communities                                                                                      1
#                           Official documentation; Trade book                                                                                                                            1
# Aland Islands             Official documentation; Stack Overflow Docs; Friends network                                                                                                  1
# Albania                   Non-Stack online communities                                                                                                                                  1
#                           Official documentation; Built-in help                                                                                                                         1
# ...

# %%
country_grp['SelfTaughtTypes'].value_counts().loc['Turkey']
# Out:
# SelfTaughtTypes
# Official documentation; Stack Overflow Q&A; Stack Overflow Docs; Non-Stack online communities; Built-in help                                                             3
# Official documentation; Trade book; Stack Overflow Q&A; Non-Stack online communities; Built-in help                                                                      3
# Official documentation; Stack Overflow Q&A; Built-in help                                                                                                                2
# Official documentation; Stack Overflow Q&A; Non-Stack online communities                                                                                                 2
# Official documentation; Stack Overflow Q&A; Stack Overflow Docs; Non-Stack online communities                                                                            2
# ...

# %%
country_grp['SelfTaughtTypes'].value_counts(normalize = True).loc['Turkey']
# Out:
# SelfTaughtTypes
# Official documentation; Stack Overflow Q&A; Stack Overflow Docs; Non-Stack online communities; Built-in help                                                             0.057692
# Official documentation; Trade book; Stack Overflow Q&A; Non-Stack online communities; Built-in help                                                                      0.057692
# Official documentation; Stack Overflow Q&A; Built-in help                                                                                                                0.038462
# Official documentation; Stack Overflow Q&A; Non-Stack online communities                                                                                                 0.038462
# Official documentation; Stack Overflow Q&A; Stack Overflow Docs; Non-Stack online communities                                                                            0.038462
# ...

# %%
country_grp['Salary'].median().loc['Turkey']
# Out:
# 12745.04132231405

# %%
country_grp['Salary'].agg(['median', 'mean']).loc['Turkey']
# Out:
# median    12745.041322
# mean      17041.256267
# Name: Turkey, dtype: float64

# %%
filt = df['Country'] == 'Turkey'
df.loc[filt]['HaveWorkedLanguage']
# Out:
# Respondent
# 59                                     C#; JavaScript; SQL
# 98                              C#; JavaScript; TypeScript
# 102                                                    NaN
# 130                                                    NaN
# 720                                              Java; SQL
# 733                                              Java; SQL
# 764                                                    NaN
# 879                       C; C++; Java; JavaScript; Python
# 1076                   Java; JavaScript; Objective-C; Ruby
# 1109                                                   NaN
# 1310     C; C#; Java; JavaScript; Objective-C; PHP; Pyt...
# 1406                                                   NaN
# 1407                                                   NaN
# 1408                                                   NaN
# 1679                                                   NaN
# 1783                          Java; JavaScript; Scala; SQL
# ...

# %%
df.loc[filt]['HaveWorkedLanguage'].str.contains('R').sum()
# Out:
# 11

# %%
filt_2 = df['Country'] == 'India'
df.loc[filt_2]['HaveWorkedLanguage']
# Out:
# Respondent
# 27       Java; JavaScript; Objective-C; Python; Swift
# 62                                C#; JavaScript; SQL
# 67                               C++; C#; Objective-C
# 95                                         C; C#; SQL
# 108                                         C; Python
#                              ...
# 19055                                             NaN
# 19085                 C#; JavaScript; SQL; TypeScript
# 19091                                             NaN
# 19094                                             NaN
# 19099                                             NaN
# Name: HaveWorkedLanguage, Length: 1557, dtype: object

# %%
df.loc[filt_2]['HaveWorkedLanguage'].str.contains('R').sum()
# Out:
# 86

# %%
filt_3 = df['Country'] == 'United States'
df.loc[filt_3]['HaveWorkedLanguage']
# Out:
# Respondent
# 1                                              Swift
# 4                             Matlab; Python; R; SQL
# 7                                     Matlab; Python
# 11                                            R; SQL
# 16                                JavaScript; VB.NET
#                             ...
# 19081                                            NaN
# 19084             Java; JavaScript; PHP; Python; SQL
# 19093                                            NaN
# 19096                                    Ruby; Scala
# 19101    C#; JavaScript; Perl; PHP; SQL; VB.NET; VBA
# Name: HaveWorkedLanguage, Length: 4364, dtype: object

# %%
df.loc[filt_3]['HaveWorkedLanguage'].str.contains('R').sum()
# Out:
# 634

# %%
country_grp['HaveWorkedLanguage'].apply(lambda x: x.str.contains('Python').sum())
# Out:
# Country
# Afghanistan                 1
# Aland Islands               0
# Albania                     2
# Algeria                     1
# American Samoa              0
#                            ..
# Virgin Islands (British)    0
# Virgin Islands (USA)        0
# Zaire                       1
# Zambia                      1
# Zimbabwe                    1
# Name: HaveWorkedLanguage, Length: 165, dtype: int64

# %%
country_respondents = df['Country'].value_counts()
country_respondents
# Out:
# United States                     4364
# India                             1557
# United Kingdom                    1424
# Germany                           1337
# Canada                             874
#                                   ...
# Cayman Islands                       1
# S. Georgia & S. Sandwich Isls.       1
# Cape Verde                           1
# Virgin Islands (USA)                 1
# Ivory Coast (Cote D'Ivoire)          1
# Name: Country, Length: 165, dtype: int64

# %%
country_uses_python = country_grp['HaveWorkedLanguage'].apply(lambda x: x.str.contains('Python').sum())
country_uses_python
# Out:
# Country
# Afghanistan                 1
# Aland Islands               0
# Albania                     2
# Algeria                     1
# American Samoa              0
#                            ..
# Virgin Islands (British)    0
# Virgin Islands (USA)        0
# Zaire                       1
# Zambia                      1
# Zimbabwe                    1
# Name: HaveWorkedLanguage, Length: 165, dtype: int64

# %%
python_df = pd.concat([country_respondents, country_uses_python], axis = 'columns', sort = False)
python_df
# Out:
#                                 Country  HaveWorkedLanguage
# United States                      4364                1244
# India                              1557                 231
# United Kingdom                     1424                 318
# Germany                            1337                 318
# Canada                              874                 248
# ...                                 ...                 ...
# Cayman Islands                        1                   1
# S. Georgia & S. Sandwich Isls.        1                   0
# Cape Verde                            1                   1
# Virgin Islands (USA)                  1                   0
# Ivory Coast (Cote D'Ivoire)           1                   0
#
# [165 rows x 2 columns]

# %%
python_df.rename(columns={'Country' : 'NumRespondents', 'HaveWorkedLanguage' : 'NumKnowsPython'}, inplace = True)

# %%
python_df
# Out:
#                                 NumRespondents  NumKnowsPython
# United States                             4364            1244
# India                                     1557             231
# United Kingdom                            1424             318
# Germany                                   1337             318
# Canada                                     874             248
# ...                                        ...             ...
# Cayman Islands                               1               1
# S. Georgia & S. Sandwich Isls.               1               0
# Cape Verde                                   1               1
# Virgin Islands (USA)                         1               0
# Ivory Coast (Cote D'Ivoire)                  1               0
#
# [165 rows x 2 columns]

# %%
python_df['PctKnowsPython'] = (python_df['NumKnowsPython']/python_df['NumRespondents'])* 100

# %%
python_df
# Out:
#                                 NumRespondents  NumKnowsPython  PctKnowsPython
# United States                             4364            1244       28.505958
# India                                     1557             231       14.836224
# United Kingdom                            1424             318       22.331461
# Germany                                   1337             318       23.784592
# Canada                                     874             248       28.375286
# ...                                        ...             ...             ...
# Cayman Islands                               1               1      100.000000
# S. Georgia & S. Sandwich Isls.               1               0        0.000000
# Cape Verde                                   1               1      100.000000
# Virgin Islands (USA)                         1               0        0.000000
# Ivory Coast (Cote D'Ivoire)                  1               0        0.000000
#
# [165 rows x 3 columns]

# %%
python_df.sort_values(by = 'PctKnowsPython', ascending = False)
# Out:
#                              NumRespondents  NumKnowsPython  PctKnowsPython
# Cape Verde                                1               1           100.0
# Zaire                                     1               1           100.0
# Cayman Islands                            1               1           100.0
# Laos                                      1               1           100.0
# Malawi                                    1               1           100.0
# ...                                     ...             ...             ...
# Bermuda                                   2               0             0.0
# Reunion (French)                          2               0             0.0
# Guyana                                    2               0             0.0
# Kyrgyzstan                                2               0             0.0
# Ivory Coast (Cote D'Ivoire)               1               0             0.0
#
# [165 rows x 3 columns]

# %%
python_df
# Out:
#                                 NumRespondents  NumKnowsPython  PctKnowsPython
# United States                             4364            1244       28.505958
# India                                     1557             231       14.836224
# United Kingdom                            1424             318       22.331461
# Germany                                   1337             318       23.784592
# Canada                                     874             248       28.375286
# ...                                        ...             ...             ...
# Cayman Islands                               1               1      100.000000
# S. Georgia & S. Sandwich Isls.               1               0        0.000000
# Cape Verde                                   1               1      100.000000
# Virgin Islands (USA)                         1               0        0.000000
# Ivory Coast (Cote D'Ivoire)                  1               0        0.000000
#
# [165 rows x 3 columns]

# %%
python_df.head()
# Out:
#                 NumRespondents  NumKnowsPython  PctKnowsPython
# United States             4364            1244       28.505958
# India                     1557             231       14.836224
# United Kingdom            1424             318       22.331461
# Germany                   1337             318       23.784592
# Canada                     874             248       28.375286

# %%
python_df.loc['Turkey']
# Out:
# NumRespondents    146.000000
# NumKnowsPython     23.000000
# PctKnowsPython     15.753425
# Name: Turkey, dtype: float64

# %%
python_df.loc['India']
# Out:
# NumRespondents    1557.000000
# NumKnowsPython     231.000000
# PctKnowsPython      14.836224
# Name: India, dtype: float64

# %%
python_df.loc['United States']
# Out:
# NumRespondents    4364.000000
# NumKnowsPython    1244.000000
# PctKnowsPython      28.505958
# Name: United States, dtype: float64
