# %% [markdown]
# <a href="https://colab.research.google.com/github/dilaraesmer/miuul_python_notes/blob/main/pandas_examples_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
people = {
    "first" : ["Corey", "Jane", "John"],
    "last" : ["Schafer", "Doe", "Doe"],
    "email" : ["CoreyMSchafer@gmail.com", "JaneDoe@email.com", "JohnDoe@email.com"]
}

# %%
df = pd.DataFrame(people)
df
# Out:
#    first     last                    email
# 0  Corey  Schafer  CoreyMSchafer@gmail.com
# 1   Jane      Doe        JaneDoe@email.com
# 2   John      Doe        JohnDoe@email.com

# %%
df["email"]
# Out:
# 0    CoreyMSchafer@gmail.com
# 1          JaneDoe@email.com
# 2          JohnDoe@email.com
# Name: email, dtype: object

# %%
df
# Out:
#    first     last                    email
# 0  Corey  Schafer  CoreyMSchafer@gmail.com
# 1   Jane      Doe        JaneDoe@email.com
# 2   John      Doe        JohnDoe@email.com

# %%
df.index
# Out:
# RangeIndex(start=0, stop=3, step=1)

# %%
df.columns
# Out:
# Index(['first', 'last', 'email'], dtype='object')

# %%
df.iloc[0]
# Out:
# first                      Corey
# last                     Schafer
# email    CoreyMSchafer@gmail.com
# Name: 0, dtype: object

# %%
filt = (df['last'] == 'Doe')

# %%
df[filt]
# Out:
#   first last              email
# 1  Jane  Doe  JaneDoe@email.com
# 2  John  Doe  JohnDoe@email.com

# %%
df[df['last'] == 'Doe']
# Out:
#   first last              email
# 1  Jane  Doe  JaneDoe@email.com
# 2  John  Doe  JohnDoe@email.com

# %%
df.loc[filt]
# Out:
#   first last              email
# 1  Jane  Doe  JaneDoe@email.com
# 2  John  Doe  JohnDoe@email.com

# %%
df.loc[filt, 'email']
# Out:
# 1    JaneDoe@email.com
# 2    JohnDoe@email.com
# Name: email, dtype: object

# %%
filt = (df['last'] == 'Doe') & (df['first'] == 'John')

# %%
df.loc[filt, 'email']
# Out:
# 2    JohnDoe@email.com
# Name: email, dtype: object

# %%
filt = (df['last'] == 'Schafer') | (df['first'] == 'John')
filt
# Out:
# 0     True
# 1    False
# 2     True
# dtype: bool

# %%
df.loc[filt, 'email']
# Out:
# 0    CoreyMSchafer@gmail.com
# 2          JohnDoe@email.com
# Name: email, dtype: object

# %%
df.loc[~filt, 'email']
# Out:
# 1    JaneDoe@email.com
# Name: email, dtype: object

# %%
df.columns = ["first_name", "last_name", "email"]

# %%
df.columns = [x.upper() for x in df.columns]
df
# Out:
#   FIRST_NAME LAST_NAME                    EMAIL
# 0      Corey   Schafer  CoreyMSchafer@gmail.com
# 1       Jane       Doe        JaneDoe@email.com
# 2       John       Doe        JohnDoe@email.com

# %%
df.columns = df.columns.str.replace('_', ' ')
df
# Out:
#   FIRST NAME LAST NAME                    EMAIL
# 0      Corey   Schafer  CoreyMSchafer@gmail.com
# 1       Jane       Doe        JaneDoe@email.com
# 2       John       Doe        JohnDoe@email.com

# %%
df.columns = [x.lower() for x in df.columns]
df
# Out:
#   first name last name                    email
# 0      Corey   Schafer  CoreyMSchafer@gmail.com
# 1       Jane       Doe        JaneDoe@email.com
# 2       John       Doe        JohnDoe@email.com

# %%
df.rename(columns = {'first name' : 'first', 'last name': 'last'}, inplace = True)
df
# Out:
#    first     last                    email
# 0  Corey  Schafer  CoreyMSchafer@gmail.com
# 1   Jane      Doe        JaneDoe@email.com
# 2   John      Doe        JohnDoe@email.com

# %%
df.loc[2] = ['John', 'Smith', 'JohnSmith@email.com']

# %%
df
# Out:
#    first     last                    email
# 0  Corey  Schafer  coreymschafer@gmail.com
# 1   Jane      Doe        janedoe@email.com
# 2   John    Smith      JohnSmith@email.com

# %%
df.loc[2]
# Out:
# first                   John
# last                   Smith
# email    JohnSmith@email.com
# Name: 2, dtype: object

# %%
df.loc[2, ['last', 'email']] = ['Doe', 'JohnDoe@email.com']
df
# Out:
#    first     last                    email
# 0  Corey  Schafer  coreymschafer@gmail.com
# 1   Jane      Doe        janedoe@email.com
# 2   John      Doe        JohnDoe@email.com

# %%
df.loc[2, 'last'] = 'Doe'
df
# Out:
#    first     last                    email
# 0  Corey  Schafer  coreymschafer@gmail.com
# 1   Jane      Doe        janedoe@email.com
# 2   John      Doe        JohnDoe@email.com

# %%
filt = (df['email'] == 'JohnDoe@email.com')
df.loc[filt, 'last'] = 'Smith'

# %%
df['email'] = df['email'].str.lower()

# %%
df
# Out:
#    first     last                    email
# 0  Corey  Schafer  coreymschafer@gmail.com
# 1   Jane      Doe        janedoe@email.com
# 2   John    Smith        johndoe@email.com

# %%
df['email'].apply(len)
# Out:
# 0    23
# 1    17
# 2    17
# Name: email, dtype: int64

# %%
def update_email(email):
  return email.upper()

# %%
df['email'].apply(update_email)
# Out:
# 0    COREYMSCHAFER@GMAIL.COM
# 1          JANEDOE@EMAIL.COM
# 2          JOHNDOE@EMAIL.COM
# Name: email, dtype: object

# %%
df['email'] = df['email'].apply(update_email)
df
# Out:
#    first     last                    email
# 0  Corey  Schafer  COREYMSCHAFER@GMAIL.COM
# 1   Jane      Doe        JANEDOE@EMAIL.COM
# 2   John    Smith        JOHNDOE@EMAIL.COM

# %%
df['email'] = df['email'].apply(lambda x : x.lower())
df
# Out:
#    first     last                    email
# 0  Corey  Schafer  coreymschafer@gmail.com
# 1   Jane      Doe        janedoe@email.com
# 2   John    Smith        johndoe@email.com

# %%
df[filt]['last']
# Out:
# 2    Smith
# Name: last, dtype: object

# %%
df.apply(len)
# Out:
# first    3
# last     3
# email    3
# dtype: int64

# %%
len(df['email'])
# Out:
# 3

# %%
df.apply(len, axis = 'columns')
# Out:
# 0    3
# 1    3
# 2    3
# dtype: int64

# %%
df.apply(pd.Series.min)
# Out:
# first                      Corey
# last                         Doe
# email    coreymschafer@gmail.com
# dtype: object

# %%
df.apply(lambda x: x.min())
# Out:
# first                      Corey
# last                         Doe
# email    coreymschafer@gmail.com
# dtype: object

# %%
df.applymap(len)
# Out:
#    first  last  email
# 0      5     7     23
# 1      4     3     17
# 2      4     5     17

# %%
df.applymap(str.lower)
# Out:
#    first     last                    email
# 0  corey  schafer  coreymschafer@gmail.com
# 1   jane      doe        janedoe@email.com
# 2   john    smith        johndoe@email.com

# %%
df
# Out:
#    first     last                    email
# 0  Corey  Schafer  coreymschafer@gmail.com
# 1   Jane      Doe        janedoe@email.com
# 2   John    Smith        johndoe@email.com

# %%
df['first'].map({'Corey': 'Chris', 'Jane': 'Mary'})
# Out:
# 0    Chris
# 1     Mary
# 2      NaN
# Name: first, dtype: object

# %%
df['first'] = df['first'].replace({'Corey': 'Chris', 'Jane': 'Mary'})

# %%
df
# Out:
#    first     last                    email
# 0  Chris  Schafer  coreymschafer@gmail.com
# 1   Mary      Doe        janedoe@email.com
# 2   John    Smith        johndoe@email.com

# %%
pd.set_option('display.max_columns', 153)
pd.set_option('display.max_rows', 153)

# %%
df_1 = pd.read_csv("survey_results_public.csv", index_col = 'Respondent')
df_1.head()
# Out:
#                                                  Professional  \
# Respondent
# 1                                                     Student
# 2                                                     Student
# 3                                      Professional developer
# 4           Professional non-developer who sometimes write...
# 5                                      Professional developer
#
#                          ProgramHobby         Country      University  \
# Respondent
# 1                           Yes, both   United States              No
# 2                           Yes, both  United Kingdom  Yes, full-time
# 3                           Yes, both  United Kingdom              No
# 4                           Yes, both   United States              No
# 5           Yes, I program as a hobby     Switzerland              No
#
#                                   EmploymentStatus  \
# Respondent
# 1           Not employed, and not looking for work
# ...

# %%
high_salary = (df_1['Salary'] > 70000)

# %%
df_1.loc[high_salary]
# Out:
#                       Professional                               ProgramHobby  \
# Respondent
# 3           Professional developer                                  Yes, both
# 15          Professional developer                  Yes, I program as a hobby
# 18          Professional developer                                  Yes, both
# 19          Professional developer                  Yes, I program as a hobby
# 23          Professional developer                                         No
# ...                            ...                                        ...
# 51316       Professional developer                                  Yes, both
# 51320       Professional developer                                  Yes, both
# 51336       Professional developer                  Yes, I program as a hobby
# 51372       Professional developer                                         No
# 51379       Professional developer  Yes, I contribute to open source projects
#
# ...

# %%
df_1.loc[high_salary, ['Country', 'HaveWorkedLanguage', 'Salary']]
# Out:
#                    Country                                HaveWorkedLanguage  \
# Respondent
# 3           United Kingdom                                 Java; PHP; Python
# 15          United Kingdom                                  Assembly; C; C++
# 18           United States  C; Clojure; JavaScript; Matlab; Rust; SQL; Swift
# 19           United States                                               NaN
# 23                  Israel                                              Java
# ...                    ...                                               ...
# 51316        United States                               Clojure; TypeScript
# 51320        United States                               C; C++; Go; Haskell
# 51336       United Kingdom              C#; JavaScript; SQL; TypeScript; VBA
# 51372          Netherlands                            Go; JavaScript; Python
# 51379               Cyprus            JavaScript; Objective-C; Python; Swift
#
#                    Salary
# ...

# %%
working_tr = (((df_1['Country'] == 'Turkey') &
(df_1['Gender'] == 'Female') &
(df_1['HoursPerWeek'] >= 2) &
(df_1['WorkStart'] >= '3:00 AM')))
df_1.loc[working_tr]
# Out:
#                                                  Professional  \
# Respondent
# 3078                                   Professional developer
# 16741                                                 Student
# 35842       Professional non-developer who sometimes write...
# 39218                                                 Student
# 47464                                                 Student
#
#                                          ProgramHobby Country      University  \
# Respondent
# 3078                                               No  Turkey              No
# 16741       Yes, I contribute to open source projects  Turkey  Yes, full-time
# 35842                                       Yes, both  Turkey              No
# 39218                       Yes, I program as a hobby  Turkey              No
# 47464                       Yes, I program as a hobby  Turkey  Yes, full-time
#
#                               EmploymentStatus      FormalEducation  \
# Respondent
# ...

# %%
df_1['HaveWorkedLanguage']
# Out:
# Respondent
# 1                                             Swift
# 2                     JavaScript; Python; Ruby; SQL
# 3                                 Java; PHP; Python
# 4                            Matlab; Python; R; SQL
# 5                                               NaN
#                             ...
# 51388      C#; JavaScript; Python; SQL; VB.NET; VBA
# 51389                                     Java; SQL
# 51390                                           NaN
# 51391                        JavaScript; PHP; Swift
# 51392    Java; JavaScript; PHP; Python; Ruby; Swift
# Name: HaveWorkedLanguage, Length: 51392, dtype: object

# %%
filt_1 = df_1['HaveWorkedLanguage'].str.contains('Python', na=False)
df_1.loc[filt_1, 'HaveWorkedLanguage']
# Out:
# Respondent
# 2                            JavaScript; Python; Ruby; SQL
# 3                                        Java; PHP; Python
# 4                                   Matlab; Python; R; SQL
# 7                                           Matlab; Python
# 8        CoffeeScript; Clojure; Elixir; Erlang; Haskell...
#                                ...
# 51379               JavaScript; Objective-C; Python; Swift
# 51382                                   JavaScript; Python
# 51386                  C#; JavaScript; PHP; Python; R; SQL
# 51388             C#; JavaScript; Python; SQL; VB.NET; VBA
# 51392           Java; JavaScript; PHP; Python; Ruby; Swift
# Name: HaveWorkedLanguage, Length: 11704, dtype: object

# %%
filt_1
# Out:
# Respondent
# 1        False
# 2         True
# 3         True
# 4         True
# 5        False
#          ...
# 51388     True
# 51389    False
# 51390    False
# 51391    False
# 51392     True
# Name: HaveWorkedLanguage, Length: 51392, dtype: bool

# %%
df_1[filt_1]
# Out:
#                                                  Professional  \
# Respondent
# 2                                                     Student
# 3                                      Professional developer
# 4           Professional non-developer who sometimes write...
# 7           Professional non-developer who sometimes write...
# 8                                      Professional developer
# ...                                                       ...
# 51379                                  Professional developer
# 51382       Professional non-developer who sometimes write...
# 51386                     Used to be a professional developer
# 51388                                  Professional developer
# 51392       Professional non-developer who sometimes write...
#
#                                          ProgramHobby         Country  \
# Respondent
# 2                                           Yes, both  United Kingdom
# ...

# %%
countries = ['Turkey', 'United Kingdom', 'India', 'Cyprus', 'Germany']
filt = df_1['Country'].isin(countries)
df_1.loc[filt, 'Country']
# Out:
# Respondent
# 2        United Kingdom
# 3        United Kingdom
# 13       United Kingdom
# 14              Germany
# 15       United Kingdom
#               ...
# 51376    United Kingdom
# 51377           Germany
# 51378    United Kingdom
# 51379            Cyprus
# 51386    United Kingdom
# Name: Country, Length: 14126, dtype: object

# %%
schema_df = pd.read_csv('survey_results_schema.csv', index_col = 'Column')
schema_df
# Out:
#                                                                Question
# Column
# Respondent                                         Respondent ID number
# Professional                 Which of the following best describes you?
# ProgramHobby          Do you program as a hobby or contribute to ope...
# Country                         In which country do you currently live?
# University            Are you currently enrolled in a formal, degree...
# ...                                                                 ...
# QuestionsInteresting                     The questions were interesting
# QuestionsConfusing                         The questions were confusing
# InterestedAnswers     I'm interested in learning how other developer...
# Salary                What is your current annual base salary, befor...
# ExpectedSalary        You said before that you are currently learnin...
#
# [154 rows x 1 columns]

# %%
schema_df.loc['Salary']
# Out:
# Question    What is your current annual base salary, befor...
# Name: Salary, dtype: object

# %%
schema_df.loc['Salary', 'Question']
# Out:
# 'What is your current annual base salary, before taxes, and excluding bonuses, grants, or other compensation?'

# %%
schema_df.sort_index()
# Out:
#                                                                 Question
# Column
# AnnoyingUI                      It annoys me when software has a poor UI
# AssessJobCommute       When you're assessing potential jobs to apply ...
# AssessJobCompensation  When you're assessing potential jobs to apply ...
# AssessJobDept          When you're assessing potential jobs to apply ...
# AssessJobDiversity     When you're assessing potential jobs to apply ...
# ...                                                                  ...
# WorkPayCare            I don't really care what I work on, so long as...
# WorkStart              Suppose you could choose your own working hour...
# YearsCodedJob          For how many years have you coded as part of y...
# YearsCodedJobPast      For how many years did you code as part of you...
# YearsProgram           How long has it been since you first learned h...
#
# [154 rows x 1 columns]

# %%
schema_df.sort_index(inplace = True)

# %%
schema_df
# Out:
#                                                                 Question
# Column
# AnnoyingUI                      It annoys me when software has a poor UI
# AssessJobCommute       When you're assessing potential jobs to apply ...
# AssessJobCompensation  When you're assessing potential jobs to apply ...
# AssessJobDept          When you're assessing potential jobs to apply ...
# AssessJobDiversity     When you're assessing potential jobs to apply ...
# ...                                                                  ...
# WorkPayCare            I don't really care what I work on, so long as...
# WorkStart              Suppose you could choose your own working hour...
# YearsCodedJob          For how many years have you coded as part of y...
# YearsCodedJobPast      For how many years did you code as part of you...
# YearsProgram           How long has it been since you first learned h...
#
# [154 rows x 1 columns]
