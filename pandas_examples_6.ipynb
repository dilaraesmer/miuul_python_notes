# %% [markdown]
# <a href="https://colab.research.google.com/github/dilaraesmer/miuul_python_notes/blob/main/pandas_examples_6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv('survey_results_public.csv', index_col = 'Respondent')
schema_df = pd.read_csv('survey_results_schema.csv', index_col = 'Column')

# %%
pd.set_option('display.max_columns', 315)
pd.set_option('display.max_rows', 315)

# %%
df.head()
# Out:
#                                                  Professional  \
# Respondent
# 1                                                     Student
# 2                                                     Student
# 3                                      Professional developer
# 4           Professional non-developer who sometimes write...
# 5                                      Professional developer
#
#                          ProgramHobby         Country      University  \
# Respondent
# 1                           Yes, both   United States              No
# 2                           Yes, both  United Kingdom  Yes, full-time
# 3                           Yes, both  United Kingdom              No
# 4                           Yes, both   United States              No
# 5           Yes, I program as a hobby     Switzerland              No
#
#                                   EmploymentStatus  \
# Respondent
# 1           Not employed, and not looking for work
# ...

# %%
filt = (df['Country'] == 'Turkey')
turkey_df = df.loc[filt]
turkey_df.head()
# Out:
#                       Professional               ProgramHobby Country  \
# Respondent
# 59          Professional developer                         No  Turkey
# 98          Professional developer                         No  Turkey
# 102                  None of these  Yes, I program as a hobby  Turkey
# 130         Professional developer  Yes, I program as a hobby  Turkey
# 720         Professional developer                         No  Turkey
#
#                 University    EmploymentStatus         FormalEducation  \
# Respondent
# 59          Yes, part-time  Employed full-time       Bachelor's degree
# 98                      No  Employed full-time       Bachelor's degree
# 102         Yes, part-time  Employed full-time       Bachelor's degree
# 130                     No  Employed full-time  I prefer not to answer
# 720                     No  Employed full-time       Bachelor's degree
#
#                                                MajorUndergrad  \
# Respondent
# ...

# %%
turkey_df.to_csv('modified.csv')

# %%
turkey_df.to_csv('modified.tsv', sep='\t')

# %%
turkey_df.to_excel('modified.xlsx')

# %%
test = pd.read_excel('modified.xlsx', index_col = 'Respondent')

# %%
test
# Out:
#                                                  Professional  \
# Respondent
# 59                                     Professional developer
# 98                                     Professional developer
# 102                                             None of these
# 130                                    Professional developer
# 720                                    Professional developer
# ...                                                       ...
# 49643                                                 Student
# 50038                                                 Student
# 50327                                  Professional developer
# 50344                                  Professional developer
# 51158       Professional non-developer who sometimes write...
#
#                          ProgramHobby Country      University  \
# Respondent
# 59                                 No  Turkey  Yes, part-time
# 98                                 No  Turkey              No
# ...

# %%
test.head()
# Out:
#                       Professional               ProgramHobby Country  \
# Respondent
# 59          Professional developer                         No  Turkey
# 98          Professional developer                         No  Turkey
# 102                  None of these  Yes, I program as a hobby  Turkey
# 130         Professional developer  Yes, I program as a hobby  Turkey
# 720         Professional developer                         No  Turkey
#
#                 University    EmploymentStatus         FormalEducation  \
# Respondent
# 59          Yes, part-time  Employed full-time       Bachelor's degree
# 98                      No  Employed full-time       Bachelor's degree
# 102         Yes, part-time  Employed full-time       Bachelor's degree
# 130                     No  Employed full-time  I prefer not to answer
# 720                     No  Employed full-time       Bachelor's degree
#
#                                                MajorUndergrad  \
# Respondent
# ...

# %%
turkey_df.to_json('modified.json', orient = 'records', lines= True)

# %%
test = turkey_df.to_json('modified.json', orient = 'records', lines= True)
