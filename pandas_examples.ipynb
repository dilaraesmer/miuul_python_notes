# %% [markdown]
# <a href="https://colab.research.google.com/github/dilaraesmer/miuul_python_notes/blob/main/pandas_examples.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
df_1 = pd.read_csv('survey_results_public.csv')
df_1.head()
# Out:
#    Respondent                                       Professional  \
# 0           1                                            Student
# 1           2                                            Student
# 2           3                             Professional developer
# 3           4  Professional non-developer who sometimes write...
# 4           5                             Professional developer
#
#                 ProgramHobby         Country      University  \
# 0                  Yes, both   United States              No
# 1                  Yes, both  United Kingdom  Yes, full-time
# 2                  Yes, both  United Kingdom              No
# 3                  Yes, both   United States              No
# 4  Yes, I program as a hobby     Switzerland              No
#
#                          EmploymentStatus  \
# 0  Not employed, and not looking for work
# 1                      Employed part-time
# 2                      Employed full-time
# ...

# %%
df_1.shape
# Out:
# (51392, 154)

# %%
df_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51392 entries, 0 to 51391
# Columns: 154 entries, Respondent to ExpectedSalary
# dtypes: float64(6), int64(1), object(147)
# memory usage: 60.4+ MB

# %%
pd.set_option('display.max_columns', 154)
pd.set_option('display.max_rows', 154)
df_1
# Out:
#        Respondent                                       Professional  \
# 0               1                                            Student
# 1               2                                            Student
# 2               3                             Professional developer
# 3               4  Professional non-developer who sometimes write...
# 4               5                             Professional developer
# ...           ...                                                ...
# 51387       51388                             Professional developer
# 51388       51389                                            Student
# 51389       51390                             Professional developer
# 51390       51391                             Professional developer
# 51391       51392  Professional non-developer who sometimes write...
#
#                     ProgramHobby         Country      University  \
# 0                      Yes, both   United States              No
# ...

# %%
schema_df = pd.read_csv('survey_results_schema.csv')

# %%
schema_df.head()
# Out:
#          Column                                           Question
# 0    Respondent                               Respondent ID number
# 1  Professional         Which of the following best describes you?
# 2  ProgramHobby  Do you program as a hobby or contribute to ope...
# 3       Country            In which country do you currently live?
# 4    University  Are you currently enrolled in a formal, degree...

# %%
df_1.tail()
# Out:
#        Respondent                                       Professional  \
# 51387       51388                             Professional developer
# 51388       51389                                            Student
# 51389       51390                             Professional developer
# 51390       51391                             Professional developer
# 51391       51392  Professional non-developer who sometimes write...
#
#                     ProgramHobby        Country      University  \
# 51387  Yes, I program as a hobby  United States              No
# 51388                         No      Venezuela  Yes, full-time
# 51389  Yes, I program as a hobby         Canada              No
# 51390  Yes, I program as a hobby  United States              No
# 51391                         No        Ireland              No
#
#          EmploymentStatus                                    FormalEducation  \
# 51387  Employed full-time                                  Bachelor's degree
# ...

# %%
people = {
    "first" : ["Corey", "Jane", "John"],
    "last" : ["Scafer", "Doe", "Doe"],
    "email" : ["CoreyMScafer@gmail.com", "JaneDoe@email.com", "JohnDoe@email.com"]

}

# %%
people["email"]
# Out:
# ['CoreyMScafer@gmail.com', 'JaneDoe@email.com', 'JohnDoe@email.com']

# %%
df = pd.DataFrame(people)
df
# Out:
#    first    last                   email
# 0  Corey  Scafer  CoreyMScafer@gmail.com
# 1   Jane     Doe       JaneDoe@email.com
# 2   John     Doe       JohnDoe@email.com

# %%
df["email"]
# Out:
# 0    CoreyMScafer@gmail.com
# 1         JaneDoe@email.com
# 2         JohnDoe@email.com
# Name: email, dtype: object

# %%
type(df["email"])
# Out:
# pandas.core.series.Series

# %%
df.email
# Out:
# 0    CoreyMScafer@gmail.com
# 1         JaneDoe@email.com
# 2         JohnDoe@email.com
# Name: email, dtype: object

# %%
df[["last", "email"]]
# Out:
#      last                   email
# 0  Scafer  CoreyMScafer@gmail.com
# 1     Doe       JaneDoe@email.com
# 2     Doe       JohnDoe@email.com

# %%
df.columns
# Out:
# Index(['first', 'last', 'email'], dtype='object')

# %%
df.iloc[0]
# Out:
# first                     Corey
# last                     Scafer
# email    CoreyMScafer@gmail.com
# Name: 0, dtype: object

# %%
df.iloc[[0,1]]
# Out:
#    first    last                   email
# 0  Corey  Scafer  CoreyMScafer@gmail.com
# 1   Jane     Doe       JaneDoe@email.com

# %%
df.iloc[[0,1], 2]
# Out:
# 0    CoreyMScafer@gmail.com
# 1         JaneDoe@email.com
# Name: email, dtype: object

# %%
df.loc[[0,1], ["last", "email"]]
# Out:
#      last                   email
# 0  Scafer  CoreyMScafer@gmail.com
# 1     Doe       JaneDoe@email.com

# %%
df_1.columns
# Out:
# Index(['Respondent', 'Professional', 'ProgramHobby', 'Country', 'University',
#        'EmploymentStatus', 'FormalEducation', 'MajorUndergrad', 'HomeRemote',
#        'CompanySize',
#        ...
#        'StackOverflowMakeMoney', 'Gender', 'HighestEducationParents', 'Race',
#        'SurveyLong', 'QuestionsInteresting', 'QuestionsConfusing',
#        'InterestedAnswers', 'Salary', 'ExpectedSalary'],
#       dtype='object', length=154)

# %%
df_1['ProgramHobby']
# Out:
# 0                        Yes, both
# 1                        Yes, both
# 2                        Yes, both
# 3                        Yes, both
# 4        Yes, I program as a hobby
#                    ...
# 51387    Yes, I program as a hobby
# 51388                           No
# 51389    Yes, I program as a hobby
# 51390    Yes, I program as a hobby
# 51391                           No
# Name: ProgramHobby, Length: 51392, dtype: object

# %%
df_1['ProgramHobby'].value_counts()
# Out:
# Yes, I program as a hobby                    24801
# Yes, both                                    13756
# No                                            9787
# Yes, I contribute to open source projects     3048
# Name: ProgramHobby, dtype: int64

# %%
df_1.loc[0]
# Out:
# Respondent                                                                          1
# Professional                                                                  Student
# ProgramHobby                                                                Yes, both
# Country                                                                 United States
# University                                                                         No
# EmploymentStatus                               Not employed, and not looking for work
# FormalEducation                                                      Secondary school
# MajorUndergrad                                                                    NaN
# HomeRemote                                                                        NaN
# CompanySize                                                                       NaN
# CompanyType                                                                       NaN
# ...

# %%
df_1.loc[0, 'ProgramHobby']
# Out:
# 'Yes, both'

# %%
df_1.loc[[0,1,2], 'ProgramHobby']
# Out:
# 0    Yes, both
# 1    Yes, both
# 2    Yes, both
# Name: ProgramHobby, dtype: object

# %%
df_1.loc[0:3, 'ProgramHobby']
# Out:
# 0    Yes, both
# 1    Yes, both
# 2    Yes, both
# 3    Yes, both
# Name: ProgramHobby, dtype: object

# %%
df_1.loc[0:5, 'EducationTypes']
# Out:
# 0             Online course; Open source contributions
# 1    Online course; Self-taught; Hackathon; Open so...
# 2    Self-taught; Coding competition; Hackathon; Op...
# 3                                                  NaN
# 4                                                  NaN
# 5    Self-taught; Hackathon; Open source contributions
# Name: EducationTypes, dtype: object

# %%
df_1.loc[0:10, ['EducationTypes', 'EmploymentStatus']]
# Out:
#                                        EducationTypes  \
# 0            Online course; Open source contributions
# 1   Online course; Self-taught; Hackathon; Open so...
# 2   Self-taught; Coding competition; Hackathon; Op...
# 3                                                 NaN
# 4                                                 NaN
# 5   Self-taught; Hackathon; Open source contributions
# 6   Online course; Part-time/evening course; On-th...
# 7   Online course; On-the-job training; Self-taugh...
# 8                                                 NaN
# 9              Self-taught; Open source contributions
# 10    Online course; On-the-job training; Self-taught
#
#                                      EmploymentStatus
# 0              Not employed, and not looking for work
# 1                                  Employed part-time
# 2                                  Employed full-time
# 3                                  Employed full-time
# ...

# %%
df_1[df_1['Gender'] == 'Female'].head()
# Out:
#      Respondent                                       Professional  \
# 10           11  Professional non-developer who sometimes write...
# 13           14                             Professional developer
# 103         104                             Professional developer
# 165         166                             Professional developer
# 214         215                             Professional developer
#
#                                   ProgramHobby        Country University  \
# 10                   Yes, I program as a hobby  United States         No
# 13                                   Yes, both        Germany         No
# 103                                         No  United States         No
# 165                  Yes, I program as a hobby        Germany         No
# 214  Yes, I contribute to open source projects        Germany         No
#
#        EmploymentStatus                                    FormalEducation  \
# ...

# %%
df_1.loc[df_1['Gender'] == 'Female', ['FormalEducation','EmploymentStatus']]
# Out:
#                                          FormalEducation  \
# 10                                     Bachelor's degree
# 13     Some college/university study without earning ...
# 103                                    Bachelor's degree
# 165    Some college/university study without earning ...
# 214                                      Master's degree
# ...                                                  ...
# 51321  Some college/university study without earning ...
# 51345                                    Doctoral degree
# 51356                                    Master's degree
# 51367                                  Bachelor's degree
# 51385                                    Master's degree
#
#                                         EmploymentStatus
# 10                                    Employed full-time
# 13                                    Employed full-time
# 103                                   Employed full-time
# ...

# %%
df_1.loc[df_1['Gender'] == 'Female']['Gender'].count()
# Out:
# 2600

# %%
df_1['WorkStart'].value_counts()
# Out:
# 9:00 AM     9401
# 10:00 AM    9091
# 8:00 AM     7076
# 7:00 AM     3364
# 11:00 AM    2212
# 6:00 AM     1216
# Noon        1146
# 2:00 PM      443
# 1:00 PM      399
# 5:00 AM      294
# 8:00 PM      280
# 6:00 PM      254
# 4:00 PM      249
# 10:00 PM     212
# 3:00 PM      206
# 9:00 PM      156
# 5:00 PM      134
# 7:00 PM      127
# 4:00 AM      123
# Midnight      90
# 11:00 PM      85
# 1:00 AM       53
# 3:00 AM       50
# 2:00 AM       35
# Name: WorkStart, dtype: int64

# %%
df_new = df_1.loc[(df_1["Gender"] == "Female") &
                        (df_1["WorkStart"] == "6:00 AM") &
                        (df_1["FormalEducation"] == "Bachelor's degree"),
                        ["Gender", "WorkStart", "University"]]

# %%
df_new
# Out:
#        Gender WorkStart      University
# 10     Female   6:00 AM              No
# 5016   Female   6:00 AM  Yes, full-time
# 5452   Female   6:00 AM              No
# 5617   Female   6:00 AM              No
# 6863   Female   6:00 AM              No
# 7540   Female   6:00 AM  Yes, full-time
# 8423   Female   6:00 AM  Yes, part-time
# 10369  Female   6:00 AM              No
# 10971  Female   6:00 AM              No
# 12911  Female   6:00 AM              No
# 13069  Female   6:00 AM              No
# 14161  Female   6:00 AM              No
# 16394  Female   6:00 AM              No
# 16767  Female   6:00 AM              No
# 18378  Female   6:00 AM  Yes, full-time
# 22779  Female   6:00 AM              No
# 23783  Female   6:00 AM              No
# 25451  Female   6:00 AM              No
# 26071  Female   6:00 AM              No
# 26227  Female   6:00 AM              No
# 27412  Female   6:00 AM              No
# 27740  Female   6:00 AM              No
# ...
