# %% [markdown]
# <a href="https://colab.research.google.com/github/dilaraesmer/miuul_python_notes/blob/main/python_examples_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
people = {
    'first' : ['Corey', 'Jane', 'John'],
    'last' : ['Schafer', 'Doe', 'Doe'],
    'email' : ['CoreyMSchafer@gmail.com', 'JaneDoe@email.com', 'JohnDoe@email.com']

}

# %%
df = pd.DataFrame(people)
df
# Out:
#    first     last                    email
# 0  Corey  Schafer  CoreyMSchafer@gmail.com
# 1   Jane      Doe        JaneDoe@email.com
# 2   John      Doe        JohnDoe@email.com

# %%
df['first'] + ' ' + df['last']
# Out:
# 0    Corey Schafer
# 1         Jane Doe
# 2         John Doe
# dtype: object

# %%
df['full_name'] = df['first'] + ' ' + df['last']

# %%
df
# Out:
#    first     last                    email      full_name
# 0  Corey  Schafer  CoreyMSchafer@gmail.com  Corey Schafer
# 1   Jane      Doe        JaneDoe@email.com       Jane Doe
# 2   John      Doe        JohnDoe@email.com       John Doe

# %%
df.drop(columns = ['first', 'last'], inplace = True)

# %%
df
# Out:
#                      email      full_name
# 0  CoreyMSchafer@gmail.com  Corey Schafer
# 1        JaneDoe@email.com       Jane Doe
# 2        JohnDoe@email.com       John Doe

# %%
df['full_name'].str.split(' ', expand = True)
# Out:
#        0        1
# 0  Corey  Schafer
# 1   Jane      Doe
# 2   John      Doe

# %%
df[['first', 'last']] = df['full_name'].str.split(' ', expand = True)

# %%
df
# Out:
#                      email      full_name  first     last
# 0  CoreyMSchafer@gmail.com  Corey Schafer  Corey  Schafer
# 1        JaneDoe@email.com       Jane Doe   Jane      Doe
# 2        JohnDoe@email.com       John Doe   John      Doe

# %%
df.append({'first' : 'Tony'}, ignore_index = True)
# Out:
#                      email      full_name  first     last
# 0  CoreyMSchafer@gmail.com  Corey Schafer  Corey  Schafer
# 1        JaneDoe@email.com       Jane Doe   Jane      Doe
# 2        JohnDoe@email.com       John Doe   John      Doe
# 3                      NaN            NaN   Tony      NaN

# %%
people = {
    'first' : ['Tony', 'Steve'],
    'last' : ['Stark', 'Rogers'],
    'email' : ['IronMan@avenge.com', 'Cap@avenge.com']
}
df2 = pd.DataFrame(people)

# %%
df2
# Out:
#    first    last               email
# 0   Tony   Stark  IronMan@avenge.com
# 1  Steve  Rogers      Cap@avenge.com

# %%
df.append(df2, ignore_index = True, sort = False)
# Out:
#                      email      full_name  first     last
# 0  CoreyMSchafer@gmail.com  Corey Schafer  Corey  Schafer
# 1        JaneDoe@email.com       Jane Doe   Jane      Doe
# 2        JohnDoe@email.com       John Doe   John      Doe
# 3       IronMan@avenge.com            NaN   Tony    Stark
# 4           Cap@avenge.com            NaN  Steve   Rogers

# %%
df = df.append(df2, ignore_index = True, sort = False)

# %%
df
# Out:
#                      email      full_name  first     last
# 0  CoreyMSchafer@gmail.com  Corey Schafer  Corey  Schafer
# 1        JaneDoe@email.com       Jane Doe   Jane      Doe
# 2        JohnDoe@email.com       John Doe   John      Doe
# 3       IronMan@avenge.com            NaN   Tony    Stark
# 4           Cap@avenge.com            NaN  Steve   Rogers

# %%
df.drop(index = 4)
# Out:
#                      email      full_name  first     last
# 0  CoreyMSchafer@gmail.com  Corey Schafer  Corey  Schafer
# 1        JaneDoe@email.com       Jane Doe   Jane      Doe
# 2        JohnDoe@email.com       John Doe   John      Doe
# 3       IronMan@avenge.com            NaN   Tony    Stark

# %%
filt = df['last'] == 'Doe'
df.drop(index = df[filt].index)
# Out:
#                      email      full_name  first     last
# 0  CoreyMSchafer@gmail.com  Corey Schafer  Corey  Schafer
# 3       IronMan@avenge.com            NaN   Tony    Stark
# 4           Cap@avenge.com            NaN  Steve   Rogers

# %%
df.sort_values(by='last')
# Out:
#                      email      full_name  first     last
# 1        JaneDoe@email.com       Jane Doe   Jane      Doe
# 2        JohnDoe@email.com       John Doe   John      Doe
# 4           Cap@avenge.com            NaN  Steve   Rogers
# 0  CoreyMSchafer@gmail.com  Corey Schafer  Corey  Schafer
# 3       IronMan@avenge.com            NaN   Tony    Stark

# %%
people = {
    'first' : ['Corey', 'Jane', 'John', 'Adam'],
    'last' : ['Schafer', 'Doe', 'Doe', 'Doe'],
    'email' : ['CoreyMSchafer@gmail.com', 'JaneDoe@email.com', 'JohnDoe@email.com', 'A@email.com']

}

# %%
df = pd.DataFrame(people)
df
# Out:
#    first     last                    email
# 0  Corey  Schafer  CoreyMSchafer@gmail.com
# 1   Jane      Doe        JaneDoe@email.com
# 2   John      Doe        JohnDoe@email.com
# 3   Adam      Doe              A@email.com

# %%
df.sort_values(by='last')
# Out:
#    first     last                    email
# 1   Jane      Doe        JaneDoe@email.com
# 2   John      Doe        JohnDoe@email.com
# 3   Adam      Doe              A@email.com
# 0  Corey  Schafer  CoreyMSchafer@gmail.com

# %%
df.sort_values(by = 'last', ascending = False)
# Out:
#    first     last                    email
# 0  Corey  Schafer  CoreyMSchafer@gmail.com
# 1   Jane      Doe        JaneDoe@email.com
# 2   John      Doe        JohnDoe@email.com
# 3   Adam      Doe              A@email.com

# %%
df.sort_values(by = ['last', 'first'], ascending = False)
# Out:
#    first     last                    email
# 0  Corey  Schafer  CoreyMSchafer@gmail.com
# 2   John      Doe        JohnDoe@email.com
# 1   Jane      Doe        JaneDoe@email.com
# 3   Adam      Doe              A@email.com

# %%
df.sort_values(by = ['last', 'first'], ascending = [False, True], inplace = True)

# %%
df
# Out:
#    first     last                    email
# 0  Corey  Schafer  CoreyMSchafer@gmail.com
# 3   Adam      Doe              A@email.com
# 1   Jane      Doe        JaneDoe@email.com
# 2   John      Doe        JohnDoe@email.com

# %%
df.sort_index()
# Out:
#    first     last                    email
# 0  Corey  Schafer  CoreyMSchafer@gmail.com
# 1   Jane      Doe        JaneDoe@email.com
# 2   John      Doe        JohnDoe@email.com
# 3   Adam      Doe              A@email.com

# %%
df['last'].sort_values()
# Out:
# 3        Doe
# 1        Doe
# 2        Doe
# 0    Schafer
# Name: last, dtype: object

# %%
df = pd.read_csv('survey_results_public.csv', index_col = 'Respondent')
df.head()
# Out:
#                                                  Professional  \
# Respondent
# 1                                                     Student
# 2                                                     Student
# 3                                      Professional developer
# 4           Professional non-developer who sometimes write...
# 5                                      Professional developer
#
#                          ProgramHobby         Country      University  \
# Respondent
# 1                           Yes, both   United States              No
# 2                           Yes, both  United Kingdom  Yes, full-time
# 3                           Yes, both  United Kingdom              No
# 4                           Yes, both   United States              No
# 5           Yes, I program as a hobby     Switzerland              No
#
#                                   EmploymentStatus  \
# Respondent
# 1           Not employed, and not looking for work
# ...

# %%
pd.set_option('display.max_columns', 153)
pd.set_option('display.max_rows', 153)

# %%
df.sort_values(by = 'Country', inplace = True)

# %%
df['Country'].head(50)
# Out:
# Respondent
# 11907      Afghanistan
# 14944      Afghanistan
# 3241       Afghanistan
# 15032      Afghanistan
# 11078      Afghanistan
# 16743      Afghanistan
# 10277      Afghanistan
# 11990      Afghanistan
# 13861      Afghanistan
# 8567       Afghanistan
# 5771       Afghanistan
# 16518      Afghanistan
# 4317     Aland Islands
# 14875    Aland Islands
# 8554     Aland Islands
# 7032     Aland Islands
# 5350     Aland Islands
# 6582     Aland Islands
# 17190          Albania
# 391            Albania
# 16916          Albania
# 7494           Albania
# 11040          Albania
# 16060          Albania
# 9781           Albania
# 9730           Albania
# 14445          Albania
# 7354           Albania
# 13317          Albania
# 4311           Albania
# 9266           Albania
# 7430           Albania
# 17164          Albania
# 670            Albania
# 12475          Albania
# 11525          Albania
# 13701          Albania
# 594            Albania
# 428            Albania
# ...

# %%
df.sort_values(by=['Country', 'Salary'], ascending = [True, False], inplace = True)

# %%
df[['Country', 'Salary']].head(50)
# Out:
#                   Country         Salary
# Respondent
# 15032         Afghanistan   16143.497758
# 3241          Afghanistan    1500.000000
# 11907         Afghanistan            NaN
# 14944         Afghanistan            NaN
# 11078         Afghanistan            NaN
# 16743         Afghanistan            NaN
# 10277         Afghanistan            NaN
# 11990         Afghanistan            NaN
# 13861         Afghanistan            NaN
# 8567          Afghanistan            NaN
# 5771          Afghanistan            NaN
# 16518         Afghanistan            NaN
# 4317        Aland Islands            NaN
# 14875       Aland Islands            NaN
# 8554        Aland Islands            NaN
# 7032        Aland Islands            NaN
# 5350        Aland Islands            NaN
# 6582        Aland Islands            NaN
# 4311              Albania  172043.010753
# 16060             Albania    9032.258065
# 428               Albania    8602.150538
# ...

# %%
df['Salary'].nlargest(10)
# Out:
# Respondent
# 6744     195000.0
# 1697     195000.0
# 6718     193750.0
# 14364    192000.0
# 2371     192000.0
# 6595     190000.0
# 1353     190000.0
# 14783    188000.0
# 14799    187500.0
# 9937     187200.0
# Name: Salary, dtype: float64

# %%
df.nlargest(10, 'Salary')
# Out:
#                       Professional                               ProgramHobby  \
# Respondent
# 6744        Professional developer                  Yes, I program as a hobby
# 1697        Professional developer                                  Yes, both
# 6718        Professional developer                                  Yes, both
# 14364       Professional developer                                  Yes, both
# 2371        Professional developer                  Yes, I program as a hobby
# 6595        Professional developer                  Yes, I program as a hobby
# 1353        Professional developer                  Yes, I program as a hobby
# 14783       Professional developer  Yes, I contribute to open source projects
# 14799       Professional developer                                  Yes, both
# 9937        Professional developer                                  Yes, both
#
#                    Country University    EmploymentStatus  \
# Respondent
# ...
